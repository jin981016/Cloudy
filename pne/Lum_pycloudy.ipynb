# %%
import numpy as np
import matplotlib.pyplot as plt
import pyCloudy as pc
import pyneb as pn
from astropy import units as u
import os

# %%
emis=['H  1  1215.67A',
'H  1  1025.72A',
'H  1  4861.33A',
'H  1  6562.81A',
'O  6  1031.91A',
'O  6  1037.62A',
'He 2  949.31A',
'He 2  972.108A',
'He 2  1025.27A',
'He 2  1640.43A',
'He 2  4859A',
'He 2  4339A',
'He 2  6527A',
'He 2  6560A',
'C  4  1550.78',
'O  3  5006.84A',
'N  5  1238.82',
'N  5  1242.80',
'c  4  1548.19',
'c  4  1550.78',
'mg 2  2795.53',
'mg 2  2802.71'
]


#'Case B'
options= [
          'stop column denstiy 24',
          'stop temperature off']

# %%
path = r"/home/jin/cloudy_Test/pne/lum_v/"

N = 100
rr = np.linspace(1, N, N)
Lumin = np.linspace(35,38,N)
# Temp = np.linspace(1e4,3e5,N)
# Hd = np.linspace(2,7,N)

for ii,nn in enumerate(rr):
    folder_path = os.path.join(path, "data_%d" % nn)
    if not os.path.isdir(folder_path):
        os.makedirs(folder_path, exist_ok=True)

    model_name = "/data_%d"%(nn)
    full_name = "{0}{1}".format(folder_path,model_name)
    hden = 5
    Teff = 2.00E+5
    L = Lumin[ii]
    radius = 11.874
    c_input = pc.CloudyInput(full_name)
    c_input.set_BB(Teff=Teff,lumi_unit='Luminosity',lumi_value=L)
    c_input.set_cste_density(hden)
    c_input.set_radius(radius)
    c_input.set_iterate(0)
    c_input.set_other(options)
    c_input.set_emis_tab(emis)
    c_input.print_input(to_file = True, verbose = False)
    pc.log_.message('Running {0}'.format(model_name), calling = 'test_1')
    pc.config.cloudy_exe = '/home/jin/Cloudy/c17.03/source/cloudy.exe'
    pc.log_.timer('Starting Cloudy', quiet = True, calling = r'test_{0}'.format(nn))
    c_input.run_cloudy()
    pc.log_.timer('Cloudy ended after seconds:', calling = r'test_{0}'.format(nn))
# Out:
#    test_1.0: Cloudy ended after seconds: in 234.26363348960876
#    test_2.0: Cloudy ended after seconds: in 266.05239844322205
#    test_3.0: Cloudy ended after seconds: in 267.0619034767151
#    test_4.0: Cloudy ended after seconds: in 269.8246874809265
#    test_5.0: Cloudy ended after seconds: in 267.188764333725
#    test_6.0: Cloudy ended after seconds: in 269.92944526672363
#    test_7.0: Cloudy ended after seconds: in 267.46298813819885
#    test_8.0: Cloudy ended after seconds: in 270.9482088088989
#    test_9.0: Cloudy ended after seconds: in 269.14700388908386
#    test_10.0: Cloudy ended after seconds: in 269.21887040138245
#    test_11.0: Cloudy ended after seconds: in 269.22630643844604
#    test_12.0: Cloudy ended after seconds: in 269.535701751709
#    test_13.0: Cloudy ended after seconds: in 270.853554725647
#    test_14.0: Cloudy ended after seconds: in 267.9161238670349
#    test_15.0: Cloudy ended after seconds: in 271.31586480140686
#    test_16.0: Cloudy ended after seconds: in 278.27423000335693
#    test_17.0: Cloudy ended after seconds: in 280.4669625759125
#    test_18.0: Cloudy ended after seconds: in 272.1498124599457
#    test_19.0: Cloudy ended after seconds: in 275.4493238925934
#    test_20.0: Cloudy ended after seconds: in 276.31551003456116
#    test_21.0: Cloudy ended after seconds: in 275.2672646045685
#    test_22.0: Cloudy ended after seconds: in 273.07111716270447
#    test_23.0: Cloudy ended after seconds: in 275.7267768383026
#    test_24.0: Cloudy ended after seconds: in 274.39673137664795
#    test_25.0: Cloudy ended after seconds: in 275.39879274368286
#    test_26.0: Cloudy ended after seconds: in 273.51950764656067
#    test_27.0: Cloudy ended after seconds: in 277.6147003173828
#    test_28.0: Cloudy ended after seconds: in 278.29673290252686
#    test_29.0: Cloudy ended after seconds: in 274.2495620250702
#    test_30.0: Cloudy ended after seconds: in 274.5496690273285
#    test_31.0: Cloudy ended after seconds: in 269.8539743423462
#    test_32.0: Cloudy ended after seconds: in 271.577520608902
#    test_33.0: Cloudy ended after seconds: in 280.54766941070557
#    test_34.0: Cloudy ended after seconds: in 277.1926863193512
#    test_35.0: Cloudy ended after seconds: in 276.0198199748993
#    test_36.0: Cloudy ended after seconds: in 277.98302841186523
#    test_37.0: Cloudy ended after seconds: in 277.94122672080994
#    test_38.0: Cloudy ended after seconds: in 277.1858117580414
#    test_39.0: Cloudy ended after seconds: in 277.20325899124146
#    test_40.0: Cloudy ended after seconds: in 278.95413756370544
#    test_41.0: Cloudy ended after seconds: in 281.0872299671173
#    test_42.0: Cloudy ended after seconds: in 284.5958240032196
#    test_43.0: Cloudy ended after seconds: in 283.4966735839844
#    test_44.0: Cloudy ended after seconds: in 289.0464916229248
#    test_45.0: Cloudy ended after seconds: in 292.05139923095703
#    test_46.0: Cloudy ended after seconds: in 288.3434293270111
#    test_47.0: Cloudy ended after seconds: in 287.4278600215912
#    test_48.0: Cloudy ended after seconds: in 287.15959429740906
#    test_49.0: Cloudy ended after seconds: in 287.7877125740051
#    test_50.0: Cloudy ended after seconds: in 289.0670893192291
#    test_51.0: Cloudy ended after seconds: in 289.34863448143005
#    test_52.0: Cloudy ended after seconds: in 290.2802197933197
#    test_53.0: Cloudy ended after seconds: in 290.43234157562256
#    test_54.0: Cloudy ended after seconds: in 290.59222865104675
#    test_55.0: Cloudy ended after seconds: in 290.7045500278473
#    test_56.0: Cloudy ended after seconds: in 288.1179563999176
#    test_57.0: Cloudy ended after seconds: in 289.0652117729187
#    test_58.0: Cloudy ended after seconds: in 285.3325283527374
#    test_59.0: Cloudy ended after seconds: in 290.66053080558777
#    test_60.0: Cloudy ended after seconds: in 293.372346162796
#    test_61.0: Cloudy ended after seconds: in 289.0041706562042
#    test_62.0: Cloudy ended after seconds: in 291.13720083236694
#    test_63.0: Cloudy ended after seconds: in 287.6914732456207
#    test_64.0: Cloudy ended after seconds: in 288.1762228012085
#    test_65.0: Cloudy ended after seconds: in 285.29002261161804
#    test_66.0: Cloudy ended after seconds: in 290.8718373775482
#    test_67.0: Cloudy ended after seconds: in 290.68171215057373
#    test_68.0: Cloudy ended after seconds: in 288.41684222221375
#    test_69.0: Cloudy ended after seconds: in 292.2008066177368
#    test_70.0: Cloudy ended after seconds: in 291.9770839214325
#    test_71.0: Cloudy ended after seconds: in 293.9867694377899
#    test_72.0: Cloudy ended after seconds: in 299.70921516418457
#    test_73.0: Cloudy ended after seconds: in 296.951363325119
#    test_74.0: Cloudy ended after seconds: in 301.6023647785187
#    test_75.0: Cloudy ended after seconds: in 300.9287950992584
#    test_76.0: Cloudy ended after seconds: in 298.4411389827728
#    test_77.0: Cloudy ended after seconds: in 300.5038638114929
#    test_78.0: Cloudy ended after seconds: in 297.86941623687744
#    test_79.0: Cloudy ended after seconds: in 303.26799058914185
#    test_80.0: Cloudy ended after seconds: in 311.2658853530884
#    test_81.0: Cloudy ended after seconds: in 250.36971998214722
#    test_82.0: Cloudy ended after seconds: in 300.7604627609253
#    test_83.0: Cloudy ended after seconds: in 290.3998107910156
#    test_84.0: Cloudy ended after seconds: in 275.163122177124
#    test_85.0: Cloudy ended after seconds: in 281.9335243701935
#    test_86.0: Cloudy ended after seconds: in 295.43879413604736
#    test_87.0: Cloudy ended after seconds: in 304.492600440979
#    test_88.0: Cloudy ended after seconds: in 302.41327023506165
#    test_89.0: Cloudy ended after seconds: in 303.61987137794495
#    test_90.0: Cloudy ended after seconds: in 303.4104731082916
#    test_91.0: Cloudy ended after seconds: in 297.54966497421265
#    test_92.0: Cloudy ended after seconds: in 297.80364632606506
#    test_93.0: Cloudy ended after seconds: in 297.8984341621399
#    test_94.0: Cloudy ended after seconds: in 292.53141832351685
#    test_95.0: Cloudy ended after seconds: in 298.2375605106354
#    test_96.0: Cloudy ended after seconds: in 296.49297738075256
#    test_97.0: Cloudy ended after seconds: in 301.1189043521881
#    test_98.0: Cloudy ended after seconds: in 297.2049458026886
#    test_99.0: Cloudy ended after seconds: in 299.2977149486542
#    test_100.0: Cloudy ended after seconds: in 298.01939511299133

# %%
#'Case B'
options= [
          'stop column denstiy 24',
          'Case B',
          'stop temperature off']

# %%
path = r"/home/jin/cloudy_Test/pne/lum_v_caseB/"

N = 100
rr = np.linspace(1, N, N)
Lumin = np.linspace(35,38,N)
# Temp = np.linspace(1e4,3e5,N)
# Hd = np.linspace(2,7,N)

for ii,nn in enumerate(rr):
    folder_path = os.path.join(path, "data_%d" % nn)
    if not os.path.isdir(folder_path):
        os.makedirs(folder_path, exist_ok=True)

    model_name = "/data_%d"%(nn)
    full_name = "{0}{1}".format(folder_path,model_name)
    hden = 5
    Teff = 2.00E+5
    L = Lumin[ii]
    radius = 11.874
    c_input = pc.CloudyInput(full_name)
    c_input.set_BB(Teff=Teff,lumi_unit='Luminosity',lumi_value=L)
    c_input.set_cste_density(hden)
    c_input.set_radius(radius)
    c_input.set_iterate(0)
    c_input.set_other(options)
    c_input.set_emis_tab(emis)
    c_input.print_input(to_file = True, verbose = False)
    pc.log_.message('Running {0}'.format(model_name), calling = 'test_1')
    pc.config.cloudy_exe = '/home/jin/Cloudy/c17.03/source/cloudy.exe'
    pc.log_.timer('Starting Cloudy', quiet = True, calling = r'test_{0}'.format(nn))
    c_input.run_cloudy()
    pc.log_.timer('Cloudy ended after seconds:', calling = r'test_{0}'.format(nn))
# Out:
#    test_1.0: Cloudy ended after seconds: in 269.22106409072876
#    test_2.0: Cloudy ended after seconds: in 270.65486216545105
#    test_3.0: Cloudy ended after seconds: in 273.06481981277466
#    test_4.0: Cloudy ended after seconds: in 269.86262679100037
#    test_5.0: Cloudy ended after seconds: in 273.6615219116211
#    test_6.0: Cloudy ended after seconds: in 275.4084892272949
#    test_7.0: Cloudy ended after seconds: in 273.28557658195496
#    test_8.0: Cloudy ended after seconds: in 276.8111000061035
#    test_9.0: Cloudy ended after seconds: in 274.74463272094727
#    test_10.0: Cloudy ended after seconds: in 278.1063349246979
#    test_11.0: Cloudy ended after seconds: in 275.77366948127747
#    test_12.0: Cloudy ended after seconds: in 270.5169839859009
#    test_13.0: Cloudy ended after seconds: in 273.36264657974243
#    test_14.0: Cloudy ended after seconds: in 274.15878796577454
#    test_15.0: Cloudy ended after seconds: in 276.44495034217834
#    test_16.0: Cloudy ended after seconds: in 276.150102853775
#    test_17.0: Cloudy ended after seconds: in 274.45867562294006
#    test_18.0: Cloudy ended after seconds: in 279.047949552536
#    test_19.0: Cloudy ended after seconds: in 280.340309381485
#    test_20.0: Cloudy ended after seconds: in 275.29439306259155
#    test_21.0: Cloudy ended after seconds: in 275.4569389820099
#    test_22.0: Cloudy ended after seconds: in 272.56218338012695
#    test_23.0: Cloudy ended after seconds: in 279.31451439857483
#    test_24.0: Cloudy ended after seconds: in 273.11799216270447
#    test_25.0: Cloudy ended after seconds: in 277.02215552330017
#    test_26.0: Cloudy ended after seconds: in 277.9915716648102
#    test_27.0: Cloudy ended after seconds: in 278.3747978210449
#    test_28.0: Cloudy ended after seconds: in 279.94853949546814
#    test_29.0: Cloudy ended after seconds: in 288.04585123062134
#    test_30.0: Cloudy ended after seconds: in 287.4079656600952
#    test_31.0: Cloudy ended after seconds: in 279.8538565635681
#    test_32.0: Cloudy ended after seconds: in 282.2582082748413
#    test_33.0: Cloudy ended after seconds: in 277.9146399497986
#    test_34.0: Cloudy ended after seconds: in 280.6492006778717
#    test_35.0: Cloudy ended after seconds: in 283.25746846199036
#    test_36.0: Cloudy ended after seconds: in 280.56986355781555
#    test_37.0: Cloudy ended after seconds: in 278.29383969306946
#    test_38.0: Cloudy ended after seconds: in 281.5183045864105
#    test_39.0: Cloudy ended after seconds: in 280.6060106754303
#    test_40.0: Cloudy ended after seconds: in 283.6598484516144
#    test_41.0: Cloudy ended after seconds: in 286.8739528656006
#    test_42.0: Cloudy ended after seconds: in 287.1317985057831
#    test_43.0: Cloudy ended after seconds: in 291.296311378479
#    test_44.0: Cloudy ended after seconds: in 290.29712438583374
#    test_45.0: Cloudy ended after seconds: in 287.01290702819824
#    test_46.0: Cloudy ended after seconds: in 285.75716757774353
#    test_47.0: Cloudy ended after seconds: in 284.67260694503784
#    test_48.0: Cloudy ended after seconds: in 284.35145354270935
#    test_49.0: Cloudy ended after seconds: in 286.83711218833923
#    test_50.0: Cloudy ended after seconds: in 284.70507311820984
#    test_51.0: Cloudy ended after seconds: in 284.89252257347107
#    test_52.0: Cloudy ended after seconds: in 282.2258689403534
#    test_53.0: Cloudy ended after seconds: in 285.6754779815674
#    test_54.0: Cloudy ended after seconds: in 283.9823784828186
#    test_55.0: Cloudy ended after seconds: in 284.23356580734253
#    test_56.0: Cloudy ended after seconds: in 284.68924617767334
#    test_57.0: Cloudy ended after seconds: in 281.7815058231354
#    test_58.0: Cloudy ended after seconds: in 279.2873201370239
#    test_59.0: Cloudy ended after seconds: in 280.44854736328125
#    test_60.0: Cloudy ended after seconds: in 280.26629519462585
#    test_61.0: Cloudy ended after seconds: in 280.7775526046753
#    test_62.0: Cloudy ended after seconds: in 279.1297538280487
#    test_63.0: Cloudy ended after seconds: in 280.62044286727905
#    test_64.0: Cloudy ended after seconds: in 276.47559356689453
#    test_65.0: Cloudy ended after seconds: in 279.31734251976013
#    test_66.0: Cloudy ended after seconds: in 280.1040794849396
#    test_67.0: Cloudy ended after seconds: in 278.94716000556946
#    test_68.0: Cloudy ended after seconds: in 282.610312461853
#    test_69.0: Cloudy ended after seconds: in 288.1154398918152
#    test_70.0: Cloudy ended after seconds: in 277.5876696109772
#    test_71.0: Cloudy ended after seconds: in 280.20510053634644
#    test_72.0: Cloudy ended after seconds: in 279.91368079185486
#    test_73.0: Cloudy ended after seconds: in 285.2255117893219
#    test_74.0: Cloudy ended after seconds: in 264.5857901573181
#    test_75.0: Cloudy ended after seconds: in 259.14913153648376
#    test_76.0: Cloudy ended after seconds: in 260.4970977306366
#    test_77.0: Cloudy ended after seconds: in 252.68131279945374
#    test_78.0: Cloudy ended after seconds: in 248.72051763534546
#    test_79.0: Cloudy ended after seconds: in 194.97947430610657
#    test_80.0: Cloudy ended after seconds: in 196.5759482383728
#    test_81.0: Cloudy ended after seconds: in 192.09032249450684
#    test_82.0: Cloudy ended after seconds: in 194.40602493286133
#    test_83.0: Cloudy ended after seconds: in 196.13473081588745
#    test_84.0: Cloudy ended after seconds: in 194.97807478904724
#    test_85.0: Cloudy ended after seconds: in 195.18838620185852
#    test_86.0: Cloudy ended after seconds: in 199.9559133052826
#    test_87.0: Cloudy ended after seconds: in 198.97418642044067
#    test_88.0: Cloudy ended after seconds: in 196.7305862903595
#    test_89.0: Cloudy ended after seconds: in 195.51224303245544
#    test_90.0: Cloudy ended after seconds: in 193.53140783309937
#    test_91.0: Cloudy ended after seconds: in 200.93549227714539
#    test_92.0: Cloudy ended after seconds: in 200.2486810684204
#    test_93.0: Cloudy ended after seconds: in 201.0381121635437
#    test_94.0: Cloudy ended after seconds: in 199.05057215690613
#    test_95.0: Cloudy ended after seconds: in 194.57277822494507
#    test_96.0: Cloudy ended after seconds: in 196.15457558631897
#    test_97.0: Cloudy ended after seconds: in 195.88006138801575
#    test_98.0: Cloudy ended after seconds: in 197.80668592453003
#    test_99.0: Cloudy ended after seconds: in 197.37787747383118
#    test_100.0: Cloudy ended after seconds: in 196.1692533493042

# %%
# N = 100
# rr = np.linspace(1, N, N)
# Lumin = np.linspace(35,38,N)

# ratio_He2 = np.zeros(N)
# ratio_H = np.zeros(N)

# L_He2_R = np.zeros(N)
# L_He2 = np.zeros(N)
# L_C4 = np.zeros(N)
# L_Mg = np.zeros(N)
# L_N5 = np.zeros(N)
# L_O6 = np.zeros(N)


# Nden_HI = np.zeros(N)
# Nden_HII = np.zeros(N)
# Nden_OVI = np.zeros(N)
# Nden_NV = np.zeros(N)
# Nden_CIV = np.zeros(N)
# # rr = np.arange(23,101,1)
# ex = []
# for ii,nn in enumerate(rr):
#     Mod = pc.CloudyModel(r"/home/jin/cloudy_Test/pne/lum_v/data_%d/data_%d"%(nn,nn))
#     try:
#         Lum_Lya = float(Mod.get_emis_vol('H__1_121567A'))
#         Lum_Lyb = float(Mod.get_emis_vol('H__1_102572A'))
#         Lum_Ha = float(Mod.get_emis_vol('H__1_656281A'))
#         Lum_Hb = float(Mod.get_emis_vol('H__1_486133A'))
#         Lum_O6 = float(Mod.get_emis_vol('O__6_103191A')) + float(Mod.get_emis_vol('O__6_103762A'))
#         Lum_O6_1 = float(Mod.get_emis_vol('O__6_103191A'))
#         Lum_O6_2 = float(Mod.get_emis_vol('O__6_103762A'))
        
#         Lum_O3 = float(Mod.get_emis_vol('O__3_500684A'))

#         Lum_C4 = float(Mod.get_emis_vol('C__4_154819A')) + float(Mod.get_emis_vol('C__4_155078A'))
#         Lum_C4_1 = float(Mod.get_emis_vol('C__4_154819A'))
#         Lum_C4_1 = float(Mod.get_emis_vol('C__4_155078A'))
#         Lum_N5 = float(Mod.get_emis_vol('N__5_123882A')) + float(Mod.get_emis_vol('N__5_124280A'))
#         Lum_N5_1 = float(Mod.get_emis_vol('N__5_123882A'))
#         Lum_N5_2 = float(Mod.get_emis_vol('N__5_124280A'))


#         Lum_Mg2 = float(Mod.get_emis_vol('MG_2_279553A'))+ float(Mod.get_emis_vol('MG_2_280271A'))
#         Lum_Mg2_1 = float(Mod.get_emis_vol('MG_2_279553A'))
#         Lum_Mg2_2 =  float(Mod.get_emis_vol('MG_2_280271A'))

#         Lum_He2_972 = float(Mod.get_emis_vol('HE_2_972108A'))
#         Lum_He2_1025 = float(Mod.get_emis_vol('HE_2_102527A'))  
#         Lum_He2_1640 = float(Mod.get_emis_vol('HE_2_164043A'))

#         Lum_He2_4339 = float(Mod.get_emis_vol('HE_2_433900A'))
#         Lum_He2_4859 = float(Mod.get_emis_vol('HE_2_485900A'))
#         Lum_He2_6529 = float(Mod.get_emis_vol('HE_2_652900A'))
#         Lum_He2_6560 = float(Mod.get_emis_vol('HE_2_656000A'))
                             
#         N_H = sum(Mod.dr*Mod.nH)
#         frac_C = 2.45E-04
#         frac_O = 4.90E-04
#         frac_N = 8.51E-05
#         frac_Mg = 3.47E-05
#         N_HI = sum(Mod.dr*Mod.nH*Mod.get_ionic('H',0))
#         N_HII = sum(Mod.dr*Mod.nH*Mod.get_ionic('H',1))
#         N_OVI = frac_O*sum(Mod.dr*Mod.nH*Mod.get_ionic('O',5))
#         N_NV = frac_N*sum(Mod.dr*Mod.nH*Mod.get_ionic('N',4))
#         N_CIV = frac_C*sum(Mod.dr*Mod.nH*Mod.get_ionic('C',3))
#         # L_He2[ii] = Lum_He2
#         # L_He2_R[ii] = Lum_He2_R
        

#         ratio_He2[ii] = Lum_He2_1025 / Lum_He2_972
#         ratio_H[ii] =  Lum_Ha / Lum_Hb
#         L_C4[ii] = Lum_C4
#         L_Mg[ii] = Lum_Mg2
#         L_N5[ii] = Lum_N5
#         L_O6[ii] = Lum_O6

#         Nden_HI[ii] = N_HI
#         Nden_HII[ii] = N_HII 
#         Nden_OVI[ii] = N_OVI
#         Nden_NV[ii] = N_NV
#         Nden_CIV[ii] = N_CIV
#     except AttributeError:
#         ex.append(nn)
#         print('error  = %d'%(nn))
